# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda
#
# Vamos trabalhar com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd

# %%
df = pd.read_csv('..\previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   id_cliente             15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12427 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#     - Mantenha sempre a categoria mais frequente como casela de referência
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#     - Observe os parâmetros e veja se algum se alterou muito.
#
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.

# %%
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# from sklearn.model_selection import train_test_split
# from sklearn import metrics
# from sklearn.ensemble import RandomForestClassifier

# from scipy.stats import ks_2samp
import statsmodels.formula.api as smf
import statsmodels.api as sm
import patsy

# %matplotlib inline

# %%
reg = smf.ols('np.log(renda) ~ sexo + posse_de_veiculo + posse_de_imovel + C(qtd_filhos) + tipo_renda + educacao + estado_civil + tipo_residencia + idade + tempo_emprego + qt_pessoas_residencia', data = df).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     230.6
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:01:23   Log-Likelihood:                -13561.
# No. Observations:               12427   AIC:                         2.718e+04
# Df Residuals:                   12396   BIC:                         2.741e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
reg = smf.ols('np.log(renda) ~ sexo + posse_de_veiculo + posse_de_imovel + C(qtd_filhos) + tipo_renda + estado_civil + tipo_residencia + idade + tempo_emprego + qt_pessoas_residencia', data = df).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     262.3
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:01:24   Log-Likelihood:                -13593.
# No. Observations:               12427   AIC:                         2.724e+04
# Df Residuals:                   12400   BIC:                         2.744e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
reg = smf.ols('np.log(renda) ~ sexo + posse_de_veiculo + posse_de_imovel + C(qtd_filhos) + tipo_renda + estado_civil + idade + tempo_emprego + qt_pessoas_residencia', data = df).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     324.6
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:01:24   Log-Likelihood:                -13595.
# No. Observations:               12427   AIC:                         2.723e+04
# Df Residuals:                   12405   BIC:                         2.740e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
df1 = df[(df.qtd_filhos != 4) & (df.qtd_filhos != 5)  & (df.tipo_renda != 'Bolsista') & (df.tipo_renda != 'Pensionista')
        & (df.estado_civil != 'União') & (df.qt_pessoas_residencia != 5) & (df.qt_pessoas_residencia != 9) & (df.qt_pessoas_residencia != 15)].copy(deep=True)

# %%
reg = smf.ols('np.log(renda) ~ sexo + posse_de_veiculo + posse_de_imovel + C(qtd_filhos, Treatment(1)) + tipo_renda + estado_civil + idade + tempo_emprego + C(qt_pessoas_residencia, Treatment(2))', 
              data = df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     400.6
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:01:24   Log-Likelihood:                -12336.
# No. Observations:               11289   AIC:                         2.471e+04
# Df Residuals:                   11272   BIC:                         2.483e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# ...

# %%
df1 = df1[df1.qtd_filhos !=3]

reg = smf.ols('np.log(renda) ~ sexo + posse_de_veiculo + posse_de_imovel + C(qtd_filhos, Treatment(1)) + tipo_renda + estado_civil + idade + tempo_emprego + C(qt_pessoas_residencia, Treatment(2))', 
              data = df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     427.1
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:01:24   Log-Likelihood:                -12333.
# No. Observations:               11285   AIC:                         2.470e+04
# Df Residuals:                   11269   BIC:                         2.481e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
# # ✓
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#    # ✓
#     - Mantenha sempre a categoria mais frequente como casela de referência
#    # ✓
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#    # ✓
#
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#
#         # O modelo melhorou, houve um incremento de R² significativo, com uma equalização do R² ajustado e uma diminuição do AIC.
#
#     - Observe os parâmetros e veja se algum se alterou muito.
#
#         # Não houveram alterações significativas
#
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.
#       # O modelo parece melhor apesar da diminuição significativa de variáveis
#       # (de 11 para 9, sem contar as dummies removidas), devido a explicação
#       # feita no item 2.
