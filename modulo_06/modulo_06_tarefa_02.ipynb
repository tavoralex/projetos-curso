# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sinasc = pd.read_csv('./sinasc_ro_2019.csv')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(y= 'IDADEMAE', data = sinasc)
# Out:
# <AxesSubplot:ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y = 'PESO', data = sinasc)
# Out:
# <AxesSubplot:ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(data = sinasc, alpha = .25, x = 'IDADEMAE', bins = 25, element = 'step', kde = True)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.histplot(data = sinasc, alpha = .25, x = 'PESO', bins = 50, kde = True)
# Out:
# <AxesSubplot:xlabel='PESO', ylabel='Count'>
